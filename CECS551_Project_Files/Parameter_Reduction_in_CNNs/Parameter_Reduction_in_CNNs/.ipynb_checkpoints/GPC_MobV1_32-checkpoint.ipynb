# %% [markdown]
# # Grouped Pointwise Convolution Neural Network Implementation
#
# This notebook implements the grouped pointwise convolution neural network on MobileNet Architecture with CIFAR-10 dataset The document includes:
#
# 1.	Cloning the package from github repository
# 2.	Import Statements
# 3.	Floating Point Operations Count
# 4.	Dataset: CIFAR-10
# 5.	Base Parameters
# 6.	Cyclic Learning Rate Scheduler
# 7.	Generate MobileNet Model
# 8.	Generate Model
# 9.	Training the model
# 10.	Plotting Accuracy and Loss
# 11.	Evaluation of Results
# 12.	The Implemented Achitecture

# %% [markdown]
# # Cloning the package from github repository

# %%
import os

if not os.path.isdir('gp'):
 # !git clone -b main https://github.com/itsaravindanand/gpc-api.git gp
else:
 # !cd gp && git pull

# !cd gp && pip install .
# Out:
# Already up to date.
# Processing c:\users\itsar\cecs551_project\gp
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.22.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (2.1.4)
# Requirement already satisfied: scikit-image>=0.15.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (0.22.0)
# Requirement already satisfied: opencv-python>=4.1.2.30 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (4.8.1.78)
# Requirement already satisfied: scikit-learn>=0.21.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (1.3.2)
# Requirement already satisfied: numpy in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2023.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (10.0.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (2.33.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (2023.12.9)
# Requirement already satisfied: packaging>=21 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-learn>=0.21.0->gpc==0.1.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-learn>=0.21.0->gpc==0.1.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.22.0->gpc==0.1.1) (1.16.0)
# Building wheels for collected packages: gpc
#   Building wheel for gpc (setup.py): started
#   Building wheel for gpc (setup.py): finished with status 'done'
#   Created wheel for gpc: filename=gpc-0.1.1-py3-none-any.whl size=24930 sha256=acad637b1dc5da96494809312c891cff430c1cf0972a17b3c0899038020afcd3
#   Stored in directory: C:\Users\itsar\AppData\Local\Temp\pip-ephem-wheel-cache-f11k46ff\wheels\c9\1f\4c\74356d7b2e990778f763d26528877e2bbb67519580a5799b17
# Successfully built gpc
# Installing collected packages: gpc
#   Attempting uninstall: gpc
#     Found existing installation: gpc 0.1.1
#     Uninstalling gpc-0.1.1:
#       Successfully uninstalled gpc-0.1.1
# Successfully installed gpc-0.1.1

# %% [markdown]
# # Import Statements

# %%
import gpc.datasets
import gpc.models
import gpc.layers
import gpc.mobilenet_v1
import numpy as np
from tensorflow import keras
from tensorflow.keras import mixed_precision
import gc
import multiprocessing
import random
import os
import matplotlib.pyplot as plt
import tensorflow as tf
print("Tensorflow version:", tf.version.VERSION)
print("Keras version:", keras.__version__)
from sklearn.metrics import classification_report
# Out:
# Tensorflow version: 2.10.1
# Keras version: 2.10.0

# %% [markdown]
# # Floating Point Operations Count
#
# The provided get_flops function is designed to calculate the number of floating-point operations (FLOPs) required for a single forward pass in a TensorFlow model. Understanding FLOPs is crucial in assessing the computational complexity of neural networks.

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(
      model.call,
      input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])

  graph_info = profile(forward_pass.get_concrete_function().graph,
                          options=ProfileOptionBuilder.float_operation())

  # The //2 is necessary since `profile` counts multiply and accumulate
  # as two flops, here we report the total number of multiply accumulate ops
  flops = graph_info.total_float_ops // 2
  return flops

# %% [markdown]
# # Dataset: CIFAR-10
#
# Loads the CIFAR-10 dataset, creates the necessary directories, and saves the dataset images as PNG files.

# %%
verbose=True
root_folder = 'cifar10-as-png'
data_dir = root_folder + '/train';
test_dir = root_folder + '/test';

if not os.path.isdir(root_folder):
  x_train, y_train, x_test, y_test = gpc.datasets.load_dataset(tf.keras.datasets.cifar10, verbose=verbose, lab=False, bipolar=False)
  os.mkdir(root_folder)
  gpc.datasets.save_dataset_as_png(gpc.datasets.fix_bad_tfkeras_channel_order(x_train)*255, y_train, dest_folder_name=data_dir)
  gpc.datasets.save_dataset_as_png(gpc.datasets.fix_bad_tfkeras_channel_order(x_test)*255, y_test, dest_folder_name=test_dir)

# %% [markdown]
# # Base Parameters
#
# The batch size and epochs can be modified as per the requirement.

# %%
num_classes = 10
batch_size = 16
epochs = 50
target_size_x = 224
target_size_y = 224
seed = 12

# %% [markdown]
# # Cyclic Learning Rate Scheduler
#
# This function will aid in scheduling the learning rate as per the epoch count

# %%
train_datagen = gpc.util.create_image_generator(validation_split=0.1, rotation_range=20, width_shift_range=0.3, height_shift_range=0.3, channel_shift_range=0.0, rescale=1./255)
test_datagen = gpc.util.create_image_generator_no_augmentation(rescale=1./255)
cpus_num = max([multiprocessing.cpu_count(), 8])

def cyclic_learningRate_Scheduler(epoch):
    #gpc Cyclic Learning Rate Scheduler.
    
    base_learning = 0.001
    local_epoch = epoch % 25
    if local_epoch < 7:
       return base_learning * (1 + 0.5*local_epoch)
    else:
       return (base_learning * 4) * ( 0.85**(local_epoch-7) )

# %% [markdown]
# # Generate MobileNet Model
#
# The method gpc_mobilenetV1 provides the facility to compile, training and test the proposed architecture. All the functionalities are given in a single method for streamlined workflow, consistent configuration and ease of use.

# %%
def gpc_mobilenetV1(generate_model=False, model_fit=False, eval_results=False):
    monitor = 'val_accuracy'
    if generate_model:
        input_shape = (target_size_x, target_size_y, 3)
    else:
        input_shape = (None, None, 3)

    # Directly set the gpcType value for the required architecture
    #gpc values and the respective architecture
    # -1 => default MobileNet Architecture
    # 1 => Grouped Pointwise Convolution MobileNet Architecture with 16 channels 
    # 2 => Grouped Pointwise Convolution MobileNet Architecture with 32 channels 
    # 3 => Grouped Pointwise Convolution MobileNet Architecture with 64 channels 
    # 4 => Grouped Pointwise Convolution MobileNet Architecture with 128 channels 
    gpcType = 2  

    basefilename = 'GPC-mobilenet-CIFAR10-' + str(gpcType)
    best_result_file_name = basefilename + '-best_result.hdf5'
    print('Running: ' + basefilename)

    if gpcType == -1:
        model = gpc.mobilenet_v1.MobileNet(
            include_top=True,
            weights=None,
            input_tensor=None,
            input_shape=input_shape,
            pooling=None,
            classes=num_classes)
    else:
        model = gpc.mobilenet_v1.gpcMobileNet(
            include_top=True,
            weights=None,
            input_shape=input_shape,
            pooling=None,
            classes=num_classes,
            gpcType=gpcType)

    optimizer = keras.optimizers.RMSprop()
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy'])

    if generate_model:
        model.summary()
        print('model flops:', get_flops(model))

    save_best = keras.callbacks.ModelCheckpoint(
        filepath=best_result_file_name,
        monitor=monitor,
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode='max',
        save_freq='epoch')

    if model_fit:
        train_flow = train_datagen.flow_from_directory(
            directory=data_dir,
            subset="training",
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        validation_flow = train_datagen.flow_from_directory(
            directory=data_dir,
            subset="validation",
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        history = model.fit(
            x=train_flow,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=validation_flow,
            callbacks=[save_best, tf.keras.callbacks.LearningRateScheduler(cyclic_learningRate_Scheduler)],
            workers=cpus_num,
            max_queue_size=128
        )
        return history

    if eval_results:
        test_flow = test_datagen.flow_from_directory(
            directory=test_dir,
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        print('Best Model Results: ' + best_result_file_name)
        model = gpc.models.load_kereas_model(best_result_file_name)
        evaluated = model.evaluate(
            x=test_flow,
            batch_size=batch_size,
            use_multiprocessing=False,
            workers=cpus_num
        )
        for metric, name in zip(evaluated, ["loss", "acc"]):
            print(name, metric)
            
        x_train, y_train, x_test, y_test = gpc.datasets.load_dataset(tf.keras.datasets.cifar10, verbose=verbose, lab=False, bipolar=False)
        pred_y = model.predict(x_test)
        print("Predicted Shape:", pred_y.shape)
        pred_classes_y = np.array(list(np.argmax(pred_y, axis=1)))
        test_classes_y = np.array(list(np.argmax(y_test, axis=1)))
        print("Pred classes shape:", pred_classes_y.shape)
        print("Test classes shape:", test_classes_y.shape)
        report = classification_report(test_classes_y, pred_classes_y, digits=4)
        print(report)

    print('Finished: ' + basefilename)

# %% [markdown]
# # Generate Model

# %%
gpc_mobilenetV1(generate_model=True, model_fit=False, eval_results=False)
# Out:
# Running: GPC-mobilenet-CIFAR10-2
# Model: "gpcmobilenetv1-2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 225, 225, 3)  0           ['input_1[0][0]']
#
#  conv1 (Conv2D)                 (None, 112, 112, 32  864         ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 32  128         ['conv1[0][0]']
#                                 )
#
#  conv1_relu (ReLU)              (None, 112, 112, 32  0           ['conv1_bn[0][0]']
#                                 )
#
#  conv_dw_1 (DepthwiseConv2D)    (None, 112, 112, 32  288         ['conv1_relu[0][0]']
#                                 )
#
#  conv_dw_1_bn (BatchNormalizati  (None, 112, 112, 32  128        ['conv_dw_1[0][0]']
#  on)                            )
#
#  conv_dw_1_relu (ReLU)          (None, 112, 112, 32  0           ['conv_dw_1_bn[0][0]']
#                                 )
#
#  conv_pw_1_bn_conv (Conv2D)     (None, 112, 112, 64  2048        ['conv_dw_1_relu[0][0]']
#                                 )
#
#  conv_pw_1_bn_bn (BatchNormaliz  (None, 112, 112, 64  256        ['conv_pw_1_bn_conv[0][0]']
#  ation)                         )
#
#  conv_pw_1_bn (Activation)      (None, 112, 112, 64  0           ['conv_pw_1_bn_bn[0][0]']
#                                 )
#
#  conv_pad_2 (ZeroPadding2D)     (None, 113, 113, 64  0           ['conv_pw_1_bn[0][0]']
#                                 )
#
#  conv_dw_2 (DepthwiseConv2D)    (None, 56, 56, 64)   576         ['conv_pad_2[0][0]']
#
#  conv_dw_2_bn (BatchNormalizati  (None, 56, 56, 64)  256         ['conv_dw_2[0][0]']
#  on)
#
#  conv_dw_2_relu (ReLU)          (None, 56, 56, 64)   0           ['conv_dw_2_bn[0][0]']
#
#  conv_pw_2_bn_conv (Conv2D)     (None, 56, 56, 128)  4096        ['conv_dw_2_relu[0][0]']
#
#  conv_pw_2_bn_bn (BatchNormaliz  (None, 56, 56, 128)  512        ['conv_pw_2_bn_conv[0][0]']
#  ation)
#
#  conv_pw_2_bn (Activation)      (None, 56, 56, 128)  0           ['conv_pw_2_bn_bn[0][0]']
#
#  conv_pw_2_bn_group_interleaved  (None, 56, 56, 128)  0          ['conv_pw_2_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_dw_3 (DepthwiseConv2D)    (None, 56, 56, 128)  1152        ['conv_pw_2_bn_group_interleaved[
#                                                                  0][0]']
#
#  conv_dw_3_bn (BatchNormalizati  (None, 56, 56, 128)  512        ['conv_dw_3[0][0]']
#  on)
#
#  conv_dw_3_relu (ReLU)          (None, 56, 56, 128)  0           ['conv_dw_3_bn[0][0]']
#
#  conv_pw_3_bn_conv (Conv2D)     (None, 56, 56, 128)  4096        ['conv_dw_3_relu[0][0]']
#
#  conv_pw_3_bn_bn (BatchNormaliz  (None, 56, 56, 128)  512        ['conv_pw_3_bn_conv[0][0]']
#  ation)
#
#  conv_pw_3_bn (Activation)      (None, 56, 56, 128)  0           ['conv_pw_3_bn_bn[0][0]']
#
#  conv_pw_3_bn_group_interleaved  (None, 56, 56, 128)  0          ['conv_pw_3_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_pw_3_bn_group_interconnec  (None, 56, 56, 128)  4096       ['conv_pw_3_bn_group_interleaved[
#  t_conv (Conv2D)                                                 0][0]']
#
#  conv_pw_3_bn_group_interconnec  (None, 56, 56, 128)  512        ['conv_pw_3_bn_group_interconnect
#  t_bn (BatchNormalization)                                       _conv[0][0]']
#
#  conv_pw_3_bn_group_interconnec  (None, 56, 56, 128)  0          ['conv_pw_3_bn_group_interconnect
#  t (Activation)                                                  _bn[0][0]']
#
#  conv_pw_3_bn_inter_group_add (  (None, 56, 56, 128)  0          ['conv_pw_3_bn_group_interconnect
#  Add)                                                            [0][0]',
#                                                                   'conv_pw_3_bn[0][0]']
#
#  conv_pad_4 (ZeroPadding2D)     (None, 57, 57, 128)  0           ['conv_pw_3_bn_inter_group_add[0]
#                                                                  [0]']
#
#  conv_dw_4 (DepthwiseConv2D)    (None, 28, 28, 128)  1152        ['conv_pad_4[0][0]']
#
#  conv_dw_4_bn (BatchNormalizati  (None, 28, 28, 128)  512        ['conv_dw_4[0][0]']
#  on)
#
#  conv_dw_4_relu (ReLU)          (None, 28, 28, 128)  0           ['conv_dw_4_bn[0][0]']
#
#  conv_pw_4_bn_conv (Conv2D)     (None, 28, 28, 256)  8192        ['conv_dw_4_relu[0][0]']
#
#  conv_pw_4_bn_bn (BatchNormaliz  (None, 28, 28, 256)  1024       ['conv_pw_4_bn_conv[0][0]']
#  ation)
#
#  conv_pw_4_bn (Activation)      (None, 28, 28, 256)  0           ['conv_pw_4_bn_bn[0][0]']
#
#  conv_pw_4_bn_group_interleaved  (None, 28, 28, 256)  0          ['conv_pw_4_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_dw_5 (DepthwiseConv2D)    (None, 28, 28, 256)  2304        ['conv_pw_4_bn_group_interleaved[
#                                                                  0][0]']
#
#  conv_dw_5_bn (BatchNormalizati  (None, 28, 28, 256)  1024       ['conv_dw_5[0][0]']
#  on)
#
#  conv_dw_5_relu (ReLU)          (None, 28, 28, 256)  0           ['conv_dw_5_bn[0][0]']
#
#  conv_pw_5_bn_conv (Conv2D)     (None, 28, 28, 256)  8192        ['conv_dw_5_relu[0][0]']
#
#  conv_pw_5_bn_bn (BatchNormaliz  (None, 28, 28, 256)  1024       ['conv_pw_5_bn_conv[0][0]']
#  ation)
#
#  conv_pw_5_bn (Activation)      (None, 28, 28, 256)  0           ['conv_pw_5_bn_bn[0][0]']
#
#  conv_pw_5_bn_group_interleaved  (None, 28, 28, 256)  0          ['conv_pw_5_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_pw_5_bn_group_interconnec  (None, 28, 28, 256)  8192       ['conv_pw_5_bn_group_interleaved[
#  t_conv (Conv2D)                                                 0][0]']
#
#  conv_pw_5_bn_group_interconnec  (None, 28, 28, 256)  1024       ['conv_pw_5_bn_group_interconnect
#  t_bn (BatchNormalization)                                       _conv[0][0]']
#
#  conv_pw_5_bn_group_interconnec  (None, 28, 28, 256)  0          ['conv_pw_5_bn_group_interconnect
#  t (Activation)                                                  _bn[0][0]']
#
#  conv_pw_5_bn_inter_group_add (  (None, 28, 28, 256)  0          ['conv_pw_5_bn_group_interconnect
#  Add)                                                            [0][0]',
#                                                                   'conv_pw_5_bn[0][0]']
#
#  conv_pad_6 (ZeroPadding2D)     (None, 29, 29, 256)  0           ['conv_pw_5_bn_inter_group_add[0]
#                                                                  [0]']
#
#  conv_dw_6 (DepthwiseConv2D)    (None, 14, 14, 256)  2304        ['conv_pad_6[0][0]']
#
#  conv_dw_6_bn (BatchNormalizati  (None, 14, 14, 256)  1024       ['conv_dw_6[0][0]']
#  on)
#
#  conv_dw_6_relu (ReLU)          (None, 14, 14, 256)  0           ['conv_dw_6_bn[0][0]']
#
#  conv_pw_6_bn_conv (Conv2D)     (None, 14, 14, 512)  16384       ['conv_dw_6_relu[0][0]']
#
#  conv_pw_6_bn_bn (BatchNormaliz  (None, 14, 14, 512)  2048       ['conv_pw_6_bn_conv[0][0]']
#  ation)
#
#  conv_pw_6_bn (Activation)      (None, 14, 14, 512)  0           ['conv_pw_6_bn_bn[0][0]']
#
#  conv_pw_6_bn_group_interleaved  (None, 14, 14, 512)  0          ['conv_pw_6_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_dw_7 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_6_bn_group_interleaved[
#                                                                  0][0]']
#
#  conv_dw_7_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_7[0][0]']
#  on)
#
#  conv_dw_7_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_7_bn[0][0]']
#
#  conv_pw_7_bn_conv (Conv2D)     (None, 14, 14, 512)  16384       ['conv_dw_7_relu[0][0]']
#
#  conv_pw_7_bn_bn (BatchNormaliz  (None, 14, 14, 512)  2048       ['conv_pw_7_bn_conv[0][0]']
#  ation)
#
#  conv_pw_7_bn (Activation)      (None, 14, 14, 512)  0           ['conv_pw_7_bn_bn[0][0]']
#
#  conv_pw_7_bn_group_interleaved  (None, 14, 14, 512)  0          ['conv_pw_7_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_pw_7_bn_group_interconnec  (None, 14, 14, 512)  16384      ['conv_pw_7_bn_group_interleaved[
#  t_conv (Conv2D)                                                 0][0]']
#
#  conv_pw_7_bn_group_interconnec  (None, 14, 14, 512)  2048       ['conv_pw_7_bn_group_interconnect
#  t_bn (BatchNormalization)                                       _conv[0][0]']
#
#  conv_pw_7_bn_group_interconnec  (None, 14, 14, 512)  0          ['conv_pw_7_bn_group_interconnect
#  t (Activation)                                                  _bn[0][0]']
#
#  conv_pw_7_bn_inter_group_add (  (None, 14, 14, 512)  0          ['conv_pw_7_bn_group_interconnect
#  Add)                                                            [0][0]',
#                                                                   'conv_pw_7_bn[0][0]']
#
#  conv_dw_8 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_7_bn_inter_group_add[0]
#                                                                  [0]']
#
#  conv_dw_8_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_8[0][0]']
#  on)
#
#  conv_dw_8_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_8_bn[0][0]']
#
#  conv_pw_8_bn_conv (Conv2D)     (None, 14, 14, 512)  16384       ['conv_dw_8_relu[0][0]']
#
#  conv_pw_8_bn_bn (BatchNormaliz  (None, 14, 14, 512)  2048       ['conv_pw_8_bn_conv[0][0]']
#  ation)
#
#  conv_pw_8_bn (Activation)      (None, 14, 14, 512)  0           ['conv_pw_8_bn_bn[0][0]']
#
#  conv_pw_8_bn_group_interleaved  (None, 14, 14, 512)  0          ['conv_pw_8_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_pw_8_bn_group_interconnec  (None, 14, 14, 512)  16384      ['conv_pw_8_bn_group_interleaved[
#  t_conv (Conv2D)                                                 0][0]']
#
#  conv_pw_8_bn_group_interconnec  (None, 14, 14, 512)  2048       ['conv_pw_8_bn_group_interconnect
#  t_bn (BatchNormalization)                                       _conv[0][0]']
#
#  conv_pw_8_bn_group_interconnec  (None, 14, 14, 512)  0          ['conv_pw_8_bn_group_interconnect
#  t (Activation)                                                  _bn[0][0]']
#
#  conv_pw_8_bn_inter_group_add (  (None, 14, 14, 512)  0          ['conv_pw_8_bn_group_interconnect
#  Add)                                                            [0][0]',
#                                                                   'conv_pw_8_bn[0][0]']
#
#  conv_dw_9 (DepthwiseConv2D)    (None, 14, 14, 512)  4608        ['conv_pw_8_bn_inter_group_add[0]
#                                                                  [0]']
#
#  conv_dw_9_bn (BatchNormalizati  (None, 14, 14, 512)  2048       ['conv_dw_9[0][0]']
#  on)
#
#  conv_dw_9_relu (ReLU)          (None, 14, 14, 512)  0           ['conv_dw_9_bn[0][0]']
#
#  conv_pw_9_bn_conv (Conv2D)     (None, 14, 14, 512)  16384       ['conv_dw_9_relu[0][0]']
#
#  conv_pw_9_bn_bn (BatchNormaliz  (None, 14, 14, 512)  2048       ['conv_pw_9_bn_conv[0][0]']
#  ation)
#
#  conv_pw_9_bn (Activation)      (None, 14, 14, 512)  0           ['conv_pw_9_bn_bn[0][0]']
#
#  conv_pw_9_bn_group_interleaved  (None, 14, 14, 512)  0          ['conv_pw_9_bn[0][0]']
#   (InterleaveChannels)
#
#  conv_pw_9_bn_group_interconnec  (None, 14, 14, 512)  16384      ['conv_pw_9_bn_group_interleaved[
#  t_conv (Conv2D)                                                 0][0]']
#
#  conv_pw_9_bn_group_interconnec  (None, 14, 14, 512)  2048       ['conv_pw_9_bn_group_interconnect
#  t_bn (BatchNormalization)                                       _conv[0][0]']
#
#  conv_pw_9_bn_group_interconnec  (None, 14, 14, 512)  0          ['conv_pw_9_bn_group_interconnect
#  t (Activation)                                                  _bn[0][0]']
#
#  conv_pw_9_bn_inter_group_add (  (None, 14, 14, 512)  0          ['conv_pw_9_bn_group_interconnect
#  Add)                                                            [0][0]',
#                                                                   'conv_pw_9_bn[0][0]']
#
#  conv_dw_10 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_9_bn_inter_group_add[0]
#                                                                  [0]']
#
#  conv_dw_10_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_10[0][0]']
#  ion)
#
#  conv_dw_10_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_10_bn[0][0]']
#
#  conv_pw_10_bn_conv (Conv2D)    (None, 14, 14, 512)  16384       ['conv_dw_10_relu[0][0]']
#
#  conv_pw_10_bn_bn (BatchNormali  (None, 14, 14, 512)  2048       ['conv_pw_10_bn_conv[0][0]']
#  zation)
#
#  conv_pw_10_bn (Activation)     (None, 14, 14, 512)  0           ['conv_pw_10_bn_bn[0][0]']
#
#  conv_pw_10_bn_group_interleave  (None, 14, 14, 512)  0          ['conv_pw_10_bn[0][0]']
#  d (InterleaveChannels)
#
#  conv_pw_10_bn_group_interconne  (None, 14, 14, 512)  16384      ['conv_pw_10_bn_group_interleaved
#  ct_conv (Conv2D)                                                [0][0]']
#
#  conv_pw_10_bn_group_interconne  (None, 14, 14, 512)  2048       ['conv_pw_10_bn_group_interconnec
#  ct_bn (BatchNormalization)                                      t_conv[0][0]']
#
#  conv_pw_10_bn_group_interconne  (None, 14, 14, 512)  0          ['conv_pw_10_bn_group_interconnec
#  ct (Activation)                                                 t_bn[0][0]']
#
#  conv_pw_10_bn_inter_group_add   (None, 14, 14, 512)  0          ['conv_pw_10_bn_group_interconnec
#  (Add)                                                           t[0][0]',
#                                                                   'conv_pw_10_bn[0][0]']
#
#  conv_dw_11 (DepthwiseConv2D)   (None, 14, 14, 512)  4608        ['conv_pw_10_bn_inter_group_add[0
#                                                                  ][0]']
#
#  conv_dw_11_bn (BatchNormalizat  (None, 14, 14, 512)  2048       ['conv_dw_11[0][0]']
#  ion)
#
#  conv_dw_11_relu (ReLU)         (None, 14, 14, 512)  0           ['conv_dw_11_bn[0][0]']
#
#  conv_pw_11_bn_conv (Conv2D)    (None, 14, 14, 512)  16384       ['conv_dw_11_relu[0][0]']
#
#  conv_pw_11_bn_bn (BatchNormali  (None, 14, 14, 512)  2048       ['conv_pw_11_bn_conv[0][0]']
#  zation)
#
#  conv_pw_11_bn (Activation)     (None, 14, 14, 512)  0           ['conv_pw_11_bn_bn[0][0]']
#
#  conv_pw_11_bn_group_interleave  (None, 14, 14, 512)  0          ['conv_pw_11_bn[0][0]']
#  d (InterleaveChannels)
#
#  conv_pw_11_bn_group_interconne  (None, 14, 14, 512)  16384      ['conv_pw_11_bn_group_interleaved
#  ct_conv (Conv2D)                                                [0][0]']
#
#  conv_pw_11_bn_group_interconne  (None, 14, 14, 512)  2048       ['conv_pw_11_bn_group_interconnec
#  ct_bn (BatchNormalization)                                      t_conv[0][0]']
#
#  conv_pw_11_bn_group_interconne  (None, 14, 14, 512)  0          ['conv_pw_11_bn_group_interconnec
#  ct (Activation)                                                 t_bn[0][0]']
#
#  conv_pw_11_bn_inter_group_add   (None, 14, 14, 512)  0          ['conv_pw_11_bn_group_interconnec
#  (Add)                                                           t[0][0]',
#                                                                   'conv_pw_11_bn[0][0]']
#
#  conv_pad_12 (ZeroPadding2D)    (None, 15, 15, 512)  0           ['conv_pw_11_bn_inter_group_add[0
#                                                                  ][0]']
#
#  conv_dw_12 (DepthwiseConv2D)   (None, 7, 7, 512)    4608        ['conv_pad_12[0][0]']
#
#  conv_dw_12_bn (BatchNormalizat  (None, 7, 7, 512)   2048        ['conv_dw_12[0][0]']
#  ion)
#
#  conv_dw_12_relu (ReLU)         (None, 7, 7, 512)    0           ['conv_dw_12_bn[0][0]']
#
#  conv_pw_12_bn_conv (Conv2D)    (None, 7, 7, 1024)   32768       ['conv_dw_12_relu[0][0]']
#
#  conv_pw_12_bn_bn (BatchNormali  (None, 7, 7, 1024)  4096        ['conv_pw_12_bn_conv[0][0]']
#  zation)
#
#  conv_pw_12_bn (Activation)     (None, 7, 7, 1024)   0           ['conv_pw_12_bn_bn[0][0]']
#
#  conv_pw_12_bn_group_interleave  (None, 7, 7, 1024)  0           ['conv_pw_12_bn[0][0]']
#  d (InterleaveChannels)
#
#  conv_dw_13 (DepthwiseConv2D)   (None, 7, 7, 1024)   9216        ['conv_pw_12_bn_group_interleaved
#                                                                  [0][0]']
#
#  conv_dw_13_bn (BatchNormalizat  (None, 7, 7, 1024)  4096        ['conv_dw_13[0][0]']
#  ion)
#
#  conv_dw_13_relu (ReLU)         (None, 7, 7, 1024)   0           ['conv_dw_13_bn[0][0]']
#
#  conv_pw_13_bn_conv (Conv2D)    (None, 7, 7, 1024)   32768       ['conv_dw_13_relu[0][0]']
#
#  conv_pw_13_bn_bn (BatchNormali  (None, 7, 7, 1024)  4096        ['conv_pw_13_bn_conv[0][0]']
#  zation)
#
#  conv_pw_13_bn (Activation)     (None, 7, 7, 1024)   0           ['conv_pw_13_bn_bn[0][0]']
#
#  conv_pw_13_bn_group_interleave  (None, 7, 7, 1024)  0           ['conv_pw_13_bn[0][0]']
#  d (InterleaveChannels)
#
#  conv_pw_13_bn_group_interconne  (None, 7, 7, 1024)  32768       ['conv_pw_13_bn_group_interleaved
#  ct_conv (Conv2D)                                                [0][0]']
#
#  conv_pw_13_bn_group_interconne  (None, 7, 7, 1024)  4096        ['conv_pw_13_bn_group_interconnec
#  ct_bn (BatchNormalization)                                      t_conv[0][0]']
#
#  conv_pw_13_bn_group_interconne  (None, 7, 7, 1024)  0           ['conv_pw_13_bn_group_interconnec
#  ct (Activation)                                                 t_bn[0][0]']
#
#  conv_pw_13_bn_inter_group_add   (None, 7, 7, 1024)  0           ['conv_pw_13_bn_group_interconnec
#  (Add)                                                           t[0][0]',
#                                                                   'conv_pw_13_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['conv_pw_13_bn_inter_group_add[0
#  alAveragePooling2D)                                             ][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 1024)   0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dropout (Dropout)              (None, 1, 1, 1024)   0           ['reshape_1[0][0]']
#
#  conv_preds (Conv2D)            (None, 1, 1, 10)     10250       ['dropout[0][0]']
#
#  reshape_2 (Reshape)            (None, 10)           0           ['conv_preds[0][0]']
#
#  act_softmax (Activation)       (None, 10)           0           ['reshape_2[0][0]']
#
# ==================================================================================================
# Total params: 432,842
# Trainable params: 403,018
# Non-trainable params: 29,824
# __________________________________________________________________________________________________
# WARNING:tensorflow:From C:\Users\itsar\anaconda3\envs\tf_env_1\lib\site-packages\tensorflow\python\ops\nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# model flops: 57813022
# Finished: GPC-mobilenet-CIFAR10-2

# %% [markdown]
# # Training the model

# %%
history = gpc_mobilenetV1(generate_model=False, model_fit=True, eval_results=False)
# Out:
# Running: GPC-mobilenet-CIFAR10-2
# Found 45000 images belonging to 10 classes.
# Found 5000 images belonging to 10 classes.
# Epoch 1/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.8676 - accuracy: 0.3141
# Epoch 1: val_accuracy improved from -inf to 0.37900, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 670s 232ms/step - loss: 1.8676 - accuracy: 0.3141 - val_loss: 1.8613 - val_accuracy: 0.3790 - lr: 0.0010
# Epoch 2/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.4852 - accuracy: 0.4695
# Epoch 2: val_accuracy improved from 0.37900 to 0.43400, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 649s 231ms/step - loss: 1.4852 - accuracy: 0.4695 - val_loss: 1.8863 - val_accuracy: 0.4340 - lr: 0.0015
# Epoch 3/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.2542 - accuracy: 0.5607
# Epoch 3: val_accuracy improved from 0.43400 to 0.53040, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 650s 231ms/step - loss: 1.2542 - accuracy: 0.5607 - val_loss: 1.4360 - val_accuracy: 0.5304 - lr: 0.0020
# Epoch 4/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.1196 - accuracy: 0.6122
# Epoch 4: val_accuracy improved from 0.53040 to 0.56460, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 650s 231ms/step - loss: 1.1196 - accuracy: 0.6122 - val_loss: 1.2624 - val_accuracy: 0.5646 - lr: 0.0025
# Epoch 5/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.0403 - accuracy: 0.6380
# Epoch 5: val_accuracy improved from 0.56460 to 0.66020, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 650s 231ms/step - loss: 1.0403 - accuracy: 0.6380 - val_loss: 1.0444 - val_accuracy: 0.6602 - lr: 0.0030
# Epoch 6/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.9870 - accuracy: 0.6575
# Epoch 6: val_accuracy did not improve from 0.66020
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.9870 - accuracy: 0.6575 - val_loss: 1.0880 - val_accuracy: 0.6370 - lr: 0.0035
# Epoch 7/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.9314 - accuracy: 0.6811
# Epoch 7: val_accuracy did not improve from 0.66020
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.9314 - accuracy: 0.6811 - val_loss: 1.0434 - val_accuracy: 0.6600 - lr: 0.0040
# Epoch 8/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.8695 - accuracy: 0.7024
# Epoch 8: val_accuracy did not improve from 0.66020
# 2813/2813 [==============================] - 654s 232ms/step - loss: 0.8695 - accuracy: 0.7024 - val_loss: 1.2678 - val_accuracy: 0.6334 - lr: 0.0040
# Epoch 9/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.7969 - accuracy: 0.7275
# Epoch 9: val_accuracy improved from 0.66020 to 0.73640, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.7969 - accuracy: 0.7275 - val_loss: 0.7606 - val_accuracy: 0.7364 - lr: 0.0034
# Epoch 10/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.7249 - accuracy: 0.7481
# Epoch 10: val_accuracy did not improve from 0.73640
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.7249 - accuracy: 0.7481 - val_loss: 0.7828 - val_accuracy: 0.7320 - lr: 0.0029
# Epoch 11/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6691 - accuracy: 0.7703
# Epoch 11: val_accuracy improved from 0.73640 to 0.77540, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 650s 231ms/step - loss: 0.6691 - accuracy: 0.7703 - val_loss: 0.6648 - val_accuracy: 0.7754 - lr: 0.0025
# Epoch 12/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6250 - accuracy: 0.7869
# Epoch 12: val_accuracy improved from 0.77540 to 0.78260, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.6250 - accuracy: 0.7869 - val_loss: 0.6388 - val_accuracy: 0.7826 - lr: 0.0021
# Epoch 13/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5756 - accuracy: 0.8039
# Epoch 13: val_accuracy improved from 0.78260 to 0.80020, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.5756 - accuracy: 0.8039 - val_loss: 0.6081 - val_accuracy: 0.8002 - lr: 0.0018
# Epoch 14/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5479 - accuracy: 0.8118
# Epoch 14: val_accuracy improved from 0.80020 to 0.81400, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 650s 231ms/step - loss: 0.5479 - accuracy: 0.8118 - val_loss: 0.5580 - val_accuracy: 0.8140 - lr: 0.0015
# Epoch 15/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5236 - accuracy: 0.8197
# Epoch 15: val_accuracy improved from 0.81400 to 0.81560, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.5236 - accuracy: 0.8197 - val_loss: 0.5351 - val_accuracy: 0.8156 - lr: 0.0013
# Epoch 16/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.8287
# Epoch 16: val_accuracy improved from 0.81560 to 0.81580, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4993 - accuracy: 0.8287 - val_loss: 0.5214 - val_accuracy: 0.8158 - lr: 0.0011
# Epoch 17/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.8378
# Epoch 17: val_accuracy improved from 0.81580 to 0.83100, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4703 - accuracy: 0.8378 - val_loss: 0.4788 - val_accuracy: 0.8310 - lr: 9.2647e-04
# Epoch 18/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.8477
# Epoch 18: val_accuracy improved from 0.83100 to 0.83180, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4517 - accuracy: 0.8477 - val_loss: 0.4923 - val_accuracy: 0.8318 - lr: 7.8750e-04
# Epoch 19/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4342 - accuracy: 0.8513
# Epoch 19: val_accuracy improved from 0.83180 to 0.85060, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4342 - accuracy: 0.8513 - val_loss: 0.4377 - val_accuracy: 0.8506 - lr: 6.6937e-04
# Epoch 20/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.8548
# Epoch 20: val_accuracy did not improve from 0.85060
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4208 - accuracy: 0.8548 - val_loss: 0.4593 - val_accuracy: 0.8432 - lr: 5.6897e-04
# Epoch 21/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.8579
# Epoch 21: val_accuracy improved from 0.85060 to 0.85840, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.4121 - accuracy: 0.8579 - val_loss: 0.4120 - val_accuracy: 0.8584 - lr: 4.8362e-04
# Epoch 22/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4074 - accuracy: 0.8614
# Epoch 22: val_accuracy improved from 0.85840 to 0.85920, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4074 - accuracy: 0.8614 - val_loss: 0.4170 - val_accuracy: 0.8592 - lr: 4.1108e-04
# Epoch 23/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3944 - accuracy: 0.8625
# Epoch 23: val_accuracy did not improve from 0.85920
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3944 - accuracy: 0.8625 - val_loss: 0.4267 - val_accuracy: 0.8544 - lr: 3.4942e-04
# Epoch 24/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8713
# Epoch 24: val_accuracy improved from 0.85920 to 0.86340, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.3779 - accuracy: 0.8713 - val_loss: 0.4099 - val_accuracy: 0.8634 - lr: 2.9700e-04
# Epoch 25/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3790 - accuracy: 0.8692
# Epoch 25: val_accuracy improved from 0.86340 to 0.86560, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.3790 - accuracy: 0.8692 - val_loss: 0.4023 - val_accuracy: 0.8656 - lr: 2.5245e-04
# Epoch 26/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8542
# Epoch 26: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 654s 232ms/step - loss: 0.4205 - accuracy: 0.8542 - val_loss: 0.4380 - val_accuracy: 0.8478 - lr: 0.0010
# Epoch 27/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4585 - accuracy: 0.8443
# Epoch 27: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 661s 235ms/step - loss: 0.4585 - accuracy: 0.8443 - val_loss: 0.6213 - val_accuracy: 0.7992 - lr: 0.0015
# Epoch 28/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.8299
# Epoch 28: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 653s 232ms/step - loss: 0.5005 - accuracy: 0.8299 - val_loss: 0.6121 - val_accuracy: 0.7976 - lr: 0.0020
# Epoch 29/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5408 - accuracy: 0.8165
# Epoch 29: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.5408 - accuracy: 0.8165 - val_loss: 0.5593 - val_accuracy: 0.8158 - lr: 0.0025
# Epoch 30/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5675 - accuracy: 0.8076
# Epoch 30: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.5675 - accuracy: 0.8076 - val_loss: 0.5713 - val_accuracy: 0.8008 - lr: 0.0030
# Epoch 31/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6051 - accuracy: 0.7963
# Epoch 31: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.6051 - accuracy: 0.7963 - val_loss: 0.8078 - val_accuracy: 0.7282 - lr: 0.0035
# Epoch 32/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6268 - accuracy: 0.7871
# Epoch 32: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.6268 - accuracy: 0.7871 - val_loss: 0.8074 - val_accuracy: 0.7486 - lr: 0.0040
# Epoch 33/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.7897
# Epoch 33: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.6158 - accuracy: 0.7897 - val_loss: 0.9470 - val_accuracy: 0.7026 - lr: 0.0040
# Epoch 34/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5697 - accuracy: 0.8070
# Epoch 34: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.5697 - accuracy: 0.8070 - val_loss: 0.7055 - val_accuracy: 0.7662 - lr: 0.0034
# Epoch 35/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.8205
# Epoch 35: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.5239 - accuracy: 0.8205 - val_loss: 0.6211 - val_accuracy: 0.7990 - lr: 0.0029
# Epoch 36/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.8349
# Epoch 36: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 232ms/step - loss: 0.4859 - accuracy: 0.8349 - val_loss: 0.5372 - val_accuracy: 0.8224 - lr: 0.0025
# Epoch 37/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.8438
# Epoch 37: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4604 - accuracy: 0.8438 - val_loss: 0.4910 - val_accuracy: 0.8392 - lr: 0.0021
# Epoch 38/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4334 - accuracy: 0.8497
# Epoch 38: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.4334 - accuracy: 0.8497 - val_loss: 0.4721 - val_accuracy: 0.8432 - lr: 0.0018
# Epoch 39/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4094 - accuracy: 0.8605
# Epoch 39: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.4094 - accuracy: 0.8605 - val_loss: 0.4544 - val_accuracy: 0.8504 - lr: 0.0015
# Epoch 40/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3817 - accuracy: 0.8688
# Epoch 40: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3817 - accuracy: 0.8688 - val_loss: 0.4312 - val_accuracy: 0.8502 - lr: 0.0013
# Epoch 41/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3681 - accuracy: 0.8728
# Epoch 41: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3681 - accuracy: 0.8728 - val_loss: 0.4325 - val_accuracy: 0.8522 - lr: 0.0011
# Epoch 42/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3561 - accuracy: 0.8768
# Epoch 42: val_accuracy did not improve from 0.86560
# 2813/2813 [==============================] - 652s 231ms/step - loss: 0.3561 - accuracy: 0.8768 - val_loss: 0.4088 - val_accuracy: 0.8602 - lr: 9.2647e-04
# Epoch 43/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8834
# Epoch 43: val_accuracy improved from 0.86560 to 0.87260, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3421 - accuracy: 0.8834 - val_loss: 0.3747 - val_accuracy: 0.8726 - lr: 7.8750e-04
# Epoch 44/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8848
# Epoch 44: val_accuracy did not improve from 0.87260
# 2813/2813 [==============================] - 650s 231ms/step - loss: 0.3329 - accuracy: 0.8848 - val_loss: 0.3891 - val_accuracy: 0.8690 - lr: 6.6937e-04
# Epoch 45/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8900
# Epoch 45: val_accuracy improved from 0.87260 to 0.87740, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3204 - accuracy: 0.8900 - val_loss: 0.3691 - val_accuracy: 0.8774 - lr: 5.6897e-04
# Epoch 46/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8946
# Epoch 46: val_accuracy did not improve from 0.87740
# 2813/2813 [==============================] - 652s 232ms/step - loss: 0.3093 - accuracy: 0.8946 - val_loss: 0.3647 - val_accuracy: 0.8724 - lr: 4.8362e-04
# Epoch 47/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8934
# Epoch 47: val_accuracy improved from 0.87740 to 0.88080, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.3074 - accuracy: 0.8934 - val_loss: 0.3547 - val_accuracy: 0.8808 - lr: 4.1108e-04
# Epoch 48/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2979 - accuracy: 0.8965
# Epoch 48: val_accuracy improved from 0.88080 to 0.88160, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 652s 231ms/step - loss: 0.2979 - accuracy: 0.8965 - val_loss: 0.3569 - val_accuracy: 0.8816 - lr: 3.4942e-04
# Epoch 49/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2949 - accuracy: 0.8990
# Epoch 49: val_accuracy improved from 0.88160 to 0.88840, saving model to GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.2949 - accuracy: 0.8990 - val_loss: 0.3451 - val_accuracy: 0.8884 - lr: 2.9700e-04
# Epoch 50/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.9012
# Epoch 50: val_accuracy did not improve from 0.88840
# 2813/2813 [==============================] - 651s 231ms/step - loss: 0.2848 - accuracy: 0.9012 - val_loss: 0.3637 - val_accuracy: 0.8802 - lr: 2.5245e-04

# %% [markdown]
# # Plotting Accuracy and Loss

# %%
# Plot the accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epoch_range = range(len(acc))

plt.plot(epoch_range, acc, label='Training accuracy')
plt.plot(epoch_range, val_acc, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epoch_range, loss, label='Training loss')
plt.plot(epoch_range, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Evaluation of Results

# %%
gpc_mobilenetV1(generate_model=False, model_fit=False, eval_results=True)
# Out:
# Running: GPC-mobilenet-CIFAR10-2
# Found 10000 images belonging to 10 classes.
# Best Model Results: GPC-mobilenet-CIFAR10-2-best_result.hdf5
# 625/625 [==============================] - 23s 33ms/step - loss: 0.3115 - accuracy: 0.9082
# loss 0.31153860688209534
# acc 0.9082000255584717
# Finished: GPC-mobilenet-CIFAR10-2
# C:\Users\itsar\anaconda3\envs\tf_env_1\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\itsar\anaconda3\envs\tf_env_1\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\itsar\anaconda3\envs\tf_env_1\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # The Implemented Architecture
#
# The below code snippets depict the modified MobileNet CNN and the convolutional layers creation which performs the core methodology of creating the GPC with interleaving channels.

# %%
# Modified GPC MobileNetV1 - gpcMobileNet:
# def gpcMobileNet(input_shape=None, alpha=1.0, depth_multiplier=1, dropout=1e-3, include_top=True, weights=None, input_tensor=None, pooling=None, classes=1000, activation=keras.activations.swish, gpcType=0):
    
#     img_input = keras.layers.Input(shape=input_shape)

#     x = _conv_block(img_input, 32, alpha, strides=(2, 2))
#     x = gpcdepthwise_conv_block(x, 64, alpha, depth_multiplier, block_id=1, activation=activation, gpcType=gpcType)

#     x = gpcdepthwise_conv_block(x, 128, alpha, depth_multiplier, strides=(2, 2), block_id=2, activation=activation,
#                                 gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 128, alpha, depth_multiplier, block_id=3, activation=activation, gpcType=gpcType)

#     x = gpcdepthwise_conv_block(x, 256, alpha, depth_multiplier, strides=(2, 2), block_id=4, activation=activation,
#                                 gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 256, alpha, depth_multiplier, block_id=5, activation=activation, gpcType=gpcType)

#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, strides=(2, 2), block_id=6, activation=activation,
#                                 gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, block_id=7, activation=activation, gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, block_id=8, activation=activation, gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, block_id=9, activation=activation, gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, block_id=10, activation=activation, gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 512, alpha, depth_multiplier, block_id=11, activation=activation, gpcType=gpcType)

#     x = gpcdepthwise_conv_block(x, 1024, alpha, depth_multiplier, strides=(2, 2), block_id=12, activation=activation,
#                                 gpcType=gpcType)
#     x = gpcdepthwise_conv_block(x, 1024, alpha, depth_multiplier, block_id=13, activation=activation, gpcType=gpcType)

#     if include_top:
#         if backend.image_data_format() == 'channels_first':
#             shape = (int(1024 * alpha), 1, 1)
#         else:
#             shape = (1, 1, int(1024 * alpha))

#         x = layers.GlobalAveragePooling2D()(x)
#         x = layers.Reshape(shape, name='reshape_1')(x)
#         x = layers.Dropout(dropout, name='dropout')(x)
#         # The last dense layer should not be optimized.
#         x = layers.Conv2D(classes, (1, 1),
#                           padding='same',
#                           name='conv_preds')(x)
#         x = layers.Activation('softmax', name='act_softmax')(x)
#     else:
#         if pooling == 'avg':
#             x = layers.GlobalAveragePooling2D()(x)
#         elif pooling == 'max':
#             x = layers.GlobalMaxPooling2D()(x)

#     inputs = img_input

#     # Create model.
#     model = keras.models.Model(inputs, x, name='gpcmobilenetv1-' + str(gpcType))

#     return model

# %%
# gpcdepthwise_conv_block code:
# def gpcdepthwise_conv_block(inputs, pointwise_conv_filters, alpha,
#                             depth_multiplier=1, strides=(1, 1), block_id=1,
#                             activation=keras.activations.swish,
#                             gpcType=0):
#         channel_axis = gpc.layers.GetChannelAxis()

#     pointwise_conv_filters = int(pointwise_conv_filters * alpha)

#     if strides == (1, 1):
#         x = inputs
#     else:
#         x = layers.ZeroPadding2D(((0, 1), (0, 1)),
#                                  name='conv_pad_%d' % block_id)(inputs)
#     x = layers.DepthwiseConv2D((3, 3),
#                                padding='same' if strides == (1, 1) else 'valid',
#                                depth_multiplier=depth_multiplier,
#                                strides=strides,
#                                use_bias=False,
#                                name='conv_dw_%d' % block_id)(x)
#     x = layers.BatchNormalization(
#         axis=channel_axis, name='conv_dw_%d_bn' % block_id)(x)
#     x = layers.ReLU(6., name='conv_dw_%d_relu' % block_id)(x)
#     x = gpc.layers.gpcPointwiseConv2D(x, filters=pointwise_conv_filters, channel_axis=channel_axis,
#                                       name='conv_pw_%d_bn' % block_id, activation=activation, has_batch_norm=True,
#                                       use_bias=False, gpcType=gpcType)
#     return x

# %%
# gpcPointwiseConv2D code:
# def gpcPointwiseConv2D(last_tensor, filters=32, channel_axis=3, name=None, activation=None, has_batch_norm=True, has_batch_scale=True, use_bias=True, gpcType=0):
#     return gpcConv2D(last_tensor, filters=filters, channel_axis=channel_axis, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias, kernel_size=1, stride_size=1, padding='same', gpcType=gpcType)

# %%
# gpcConv2D | Code that decides the channel count based execution:
# def gpcConv2D(last_tensor, filters=32, channel_axis=3, name=None, activation=None, has_batch_norm=True, has_batch_scale=True, use_bias=True, kernel_size=1, stride_size=1, padding='same', gpcType=0):
#     prev_layer_channel_count = tensorflow.keras.backend.int_shape(last_tensor)[channel_axis]
#     if gpcType == 1:
#         #16 Channels
#         return gpcConv2DType2(last_tensor, filters=filters, channel_axis=channel_axis, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias, kernel_size=kernel_size, stride_size=stride_size, padding=padding, min_channels_per_group=16)
#     elif gpcType == 2:
#         #32 Channels
#         return gpcConv2DType2(last_tensor, filters=filters, channel_axis=channel_axis, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias, kernel_size=kernel_size, stride_size=stride_size, padding=padding, min_channels_per_group=32)
#     elif gpcType == 3:
#         #64 Channels
#         return gpcConv2DType2(last_tensor, filters=filters, channel_axis=channel_axis, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias, kernel_size=kernel_size, stride_size=stride_size, padding=padding, min_channels_per_group=64)
#     elif gpcType == 4:
#         #128 Channels
#         return gpcConv2DType2(last_tensor, filters=filters, channel_axis=channel_axis, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias, kernel_size=kernel_size, stride_size=stride_size, padding=padding, min_channels_per_group=128)

# %%
# The below method (gpcConv2DType2) does the following steps:
# •	This code segment from the gpcConv2DType2 function in the project report is designed to apply grouped convolutions to the input tensor, last_tensor. 
# •	It starts by determining the number of groups for the convolution based on the input and output channel counts. 
# •	If the group count is more than one, it applies a convolution operation with group-wise separation (conv2d_bn), followed by an interleaving of channels (InterleaveChannels) for enhanced feature extraction. 
# •	If the input channel count is greater or equal to the output channel count, another grouped convolution is applied for inter-group connections. 
# •	The final output tensor is the sum of the grouped convolution output and the original input tensor, which helps in maintaining feature integrity while reducing parameters.

# gpcConv2DType2 | Code that creates the GPC layer:
# def gpcConv2DType2(last_tensor,  filters=32,  channel_axis=3,  name=None, activation=None, has_batch_norm=True, has_batch_scale=True, use_bias=True, kernel_size=1, stride_size=1, padding='same', min_channels_per_group=16):
    
#     prev_layer_channel_count = tensorflow.keras.backend.int_shape(last_tensor)[channel_axis]
#     output_channel_count = filters
#     max_acceptable_divisor = (prev_layer_channel_count//min_channels_per_group)
#     group_count = gpc.util.get_max_acceptable_common_divisor(prev_layer_channel_count, output_channel_count, max_acceptable = max_acceptable_divisor)
    
#     if group_count is None: group_count=1
#     output_group_size = output_channel_count // group_count
    
#     if (group_count>1):
#     output_tensor = conv2d_bn(output_tensor, output_channel_count, kernel_size, kernel_size, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, groups=group_count, use_bias=use_bias, strides=(stride_size, stride_size), padding=padding)
#         compression_tensor = output_tensor
#         if output_group_size > 1:
#             output_tensor = InterleaveChannels(output_group_size, name=name+'_group_interleaved')(output_tensor)
#         if (prev_layer_channel_count >= output_channel_count):
#             output_tensor = conv2d_bn(output_tensor, output_channel_count, 1, 1, name=name+'_group_interconnect', activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, groups=group_count, use_bias=use_bias)
#             output_tensor = tensorflow.keras.layers.add([output_tensor, compression_tensor], name=name+'_inter_group_add')
#     else:
#         output_tensor = conv2d_bn(output_tensor, output_channel_count, kernel_size, kernel_size, name=name, activation=activation, has_batch_norm=has_batch_norm, has_batch_scale=has_batch_scale, use_bias=use_bias)
    
#     return output_tensor
