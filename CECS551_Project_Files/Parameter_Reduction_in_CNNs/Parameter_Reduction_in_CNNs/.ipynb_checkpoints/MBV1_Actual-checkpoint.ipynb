# %% [markdown]
# # Grouped Pointwise Convolution Neural Network Implementation
#
# This notebook implements the grouped pointwise convolution neural network on MobileNet Architecture with CIFAR-10 dataset

# %% [markdown]
# # Importing the package from github repository

# %%
import os
#"""
# ! rm -r k
if not os.path.isdir('gp'):
 # !git clone -b main https://github.com/itsaravindanand/gpc-api.git gp
else:
 # !cd gp && git pull
#"""
# !cd gp && pip install .
# Out:
# Cloning into 'gp'...
# Processing c:\users\itsar\cecs551_project\gp
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.22.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (2.1.4)
# Requirement already satisfied: scikit-image>=0.15.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (0.22.0)
# Requirement already satisfied: opencv-python>=4.1.2.30 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (4.8.1.78)
# Requirement already satisfied: scikit-learn>=0.21.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (1.3.2)
# Requirement already satisfied: numpy in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from gpc==0.1.1) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from pandas>=0.22.0->gpc==0.1.1) (2023.3)
# Requirement already satisfied: scipy>=1.8 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (10.0.1)
# Requirement already satisfied: imageio>=2.27 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (2.33.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (2023.12.9)
# Requirement already satisfied: packaging>=21 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (23.1)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-image>=0.15.0->gpc==0.1.1) (0.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-learn>=0.21.0->gpc==0.1.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from scikit-learn>=0.21.0->gpc==0.1.1) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\itsar\anaconda3\envs\tf_env_1\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.22.0->gpc==0.1.1) (1.16.0)
# Building wheels for collected packages: gpc
#   Building wheel for gpc (setup.py): started
#   Building wheel for gpc (setup.py): finished with status 'done'
#   Created wheel for gpc: filename=gpc-0.1.1-py3-none-any.whl size=31882 sha256=16d59d30a9f22270f0f154dffd32049c6c200a2f52c990c6d739105e48838ddf
#   Stored in directory: C:\Users\itsar\AppData\Local\Temp\pip-ephem-wheel-cache-m6fot6wf\wheels\c9\1f\4c\74356d7b2e990778f763d26528877e2bbb67519580a5799b17
# Successfully built gpc
# Installing collected packages: gpc
#   Attempting uninstall: gpc
#     Found existing installation: gpc 0.1.1
#     Uninstalling gpc-0.1.1:
#       Successfully uninstalled gpc-0.1.1
# Successfully installed gpc-0.1.1

# %% [markdown]
# # Import Statements

# %%
import gpc.datasets
import gpc.models
import gpc.layers
import gpc.mobilenet_v1
import numpy as np
from tensorflow import keras
from tensorflow.keras import mixed_precision
import gc
import multiprocessing
import random
import os
import matplotlib.pyplot as plt
import tensorflow as tf
print("Tensorflow version:", tf.version.VERSION)
print("Keras version:", keras.__version__)
from sklearn.metrics import classification_report
# Out:
# Tensorflow version: 2.10.1
# Keras version: 2.10.0

# %% [markdown]
# # Floating Point Operations Count
#
# The provided get_flops function is designed to calculate the number of floating-point operations (FLOPs) required for a single forward pass in a TensorFlow model. Understanding FLOPs is crucial in assessing the computational complexity of neural networks.

# %%
from tensorflow.python.profiler.model_analyzer import profile
from tensorflow.python.profiler.option_builder import ProfileOptionBuilder

def get_flops(model):
  forward_pass = tf.function(
      model.call,
      input_signature=[tf.TensorSpec(shape=(1,) + model.input_shape[1:])])

  graph_info = profile(forward_pass.get_concrete_function().graph,
                          options=ProfileOptionBuilder.float_operation())

  # The //2 is necessary since `profile` counts multiply and accumulate
  # as two flops, here we report the total number of multiply accumulate ops
  flops = graph_info.total_float_ops // 2
  return flops

# %% [markdown]
# # Dataset: CIFAR-10
#
# Loads the CIFAR-10 dataset, creates the necessary directories, and saves the dataset images as PNG files.

# %%
verbose=True
root_folder = 'cifar10-as-png'
data_dir = root_folder + '/train';
test_dir = root_folder + '/test';

if not os.path.isdir(root_folder):
  x_train, y_train, x_test, y_test = gpc.datasets.load_dataset(tf.keras.datasets.cifar10, verbose=verbose, lab=False, bipolar=False)
  os.mkdir(root_folder)
  gpc.datasets.save_dataset_as_png(gpc.datasets.fix_bad_tfkeras_channel_order(x_train)*255, y_train, dest_folder_name=data_dir)
  gpc.datasets.save_dataset_as_png(gpc.datasets.fix_bad_tfkeras_channel_order(x_test)*255, y_test, dest_folder_name=test_dir)
# Out:
# train shape (50000, 32, 32, 3)
# test shape (10000, 32, 32, 3)
# Original channel  0  min: 0.0  max: 255.0
# Original channel  1  min: 0.0  max: 255.0
# Original channel  2  min: 0.0  max: 255.0
# Loading RGB.
# Channel  0  min: 0.0  max: 1.0
# Channel  1  min: 0.0  max: 1.0
# Channel  2  min: 0.0  max: 1.0

# %% [markdown]
# # Base Parameters
#
# The batch size and epochs can be modified as per the requirement.

# %%
num_classes = 10
batch_size = 16
epochs = 50
target_size_x = 224
target_size_y = 224
seed = 12

# %% [markdown]
# # Cyclic Learning Rate Scheduler

# %%
train_datagen = gpc.util.create_image_generator(validation_split=0.1, rotation_range=20, width_shift_range=0.3, height_shift_range=0.3, channel_shift_range=0.0, rescale=1./255)
test_datagen = gpc.util.create_image_generator_no_augmentation(rescale=1./255)
cpus_num = max([multiprocessing.cpu_count(), 8])

def cyclic_learningRate_Scheduler(epoch):
    #gpc Cyclic Learning Rate Scheduler.
    
    base_learning = 0.001
    local_epoch = epoch % 25
    if local_epoch < 7:
       return base_learning * (1 + 0.5*local_epoch)
    else:
       return (base_learning * 4) * ( 0.85**(local_epoch-7) )

# %% [markdown]
# # Generate MobileNet Model

# %%
def gpc_mobilenetV1(generate_model=False, model_fit=False, eval_results=False):
    monitor = 'val_accuracy'
    if generate_model:
        input_shape = (target_size_x, target_size_y, 3)
    else:
        input_shape = (None, None, 3)

    # Directly set the gpcType value for the required architecture
    #gpc values and the respective architecture
    # -1 => default MobileNet Architecture
    # 1 => Grouped Pointwise Convolution MobileNet Architecture with 16 channels 
    # 2 => Grouped Pointwise Convolution MobileNet Architecture with 32 channels 
    # 3 => Grouped Pointwise Convolution MobileNet Architecture with 64 channels 
    # 4 => Grouped Pointwise Convolution MobileNet Architecture with 128 channels 
    gpcType = -1  

    basefilename = 'GPC-mobilenet-CIFAR10-' + str(gpcType)
    best_result_file_name = basefilename + '-best_result.hdf5'
    print('Running: ' + basefilename)

    if gpcType == -1:
        model = gpc.mobilenet_v1.MobileNet(
            include_top=True,
            weights=None,
            input_tensor=None,
            input_shape=input_shape,
            pooling=None,
            classes=num_classes)
    else:
        model = gpc.mobilenet_v1.gpcMobileNet(
            include_top=True,
            weights=None,
            input_shape=input_shape,
            pooling=None,
            classes=num_classes,
            gpcType=gpcType)

    optimizer = keras.optimizers.RMSprop()
    optimizer = mixed_precision.LossScaleOptimizer(optimizer)
    model.compile(
        loss='categorical_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy'])

    if generate_model:
        model.summary()
        print('model flops:', get_flops(model))

    save_best = keras.callbacks.ModelCheckpoint(
        filepath=best_result_file_name,
        monitor=monitor,
        verbose=1,
        save_best_only=True,
        save_weights_only=False,
        mode='max',
        save_freq='epoch')

    if model_fit:
        train_flow = train_datagen.flow_from_directory(
            directory=data_dir,
            subset="training",
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        validation_flow = train_datagen.flow_from_directory(
            directory=data_dir,
            subset="validation",
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        history = model.fit(
            x=train_flow,
            epochs=epochs,
            batch_size=batch_size,
            validation_data=validation_flow,
            callbacks=[save_best, tf.keras.callbacks.LearningRateScheduler(cyclic_learningRate_Scheduler)],
            workers=cpus_num,
            max_queue_size=128
        )
        return history

    if eval_results:
        test_flow = test_datagen.flow_from_directory(
            directory=test_dir,
            target_size=(target_size_x, target_size_y),
            color_mode="rgb",
            batch_size=batch_size,
            class_mode="categorical",
            shuffle=True,
            seed=seed
        )
        print('Best Model Results: ' + best_result_file_name)
        model = gpc.models.load_kereas_model(best_result_file_name)
        evaluated = model.evaluate(
            x=test_flow,
            batch_size=batch_size,
            use_multiprocessing=False,
            workers=cpus_num
        )
        for metric, name in zip(evaluated, ["loss", "acc"]):
            print(name, metric)

    print('Finished: ' + basefilename)

# %% [markdown]
# # Generate Model

# %%
gpc_mobilenetV1(generate_model=True, model_fit=False, eval_results=False)
# Out:
# Running: GPC-mobilenet-CIFAR10--1
# Model: "mobilenetv1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1_pad (ZeroPadding2D)   (None, 225, 225, 3)       0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  reshape_1 (Reshape)         (None, 1, 1, 1024)        0
#
#  dropout (Dropout)           (None, 1, 1, 1024)        0
#
#  conv_preds (Conv2D)         (None, 1, 1, 10)          10250
#
#  reshape_2 (Reshape)         (None, 10)                0
#
#  act_softmax (Activation)    (None, 10)                0
#
# =================================================================
# Total params: 3,239,114
# Trainable params: 3,217,226
# Non-trainable params: 21,888
# _________________________________________________________________
# model flops: 567751710
# Finished: GPC-mobilenet-CIFAR10--1

# %% [markdown]
# # Model Fitting

# %%
history = gpc_mobilenetV1(generate_model=False, model_fit=True, eval_results=False)
# Out:
# Running: GPC-mobilenet-CIFAR10--1
# Found 45000 images belonging to 10 classes.
# Found 5000 images belonging to 10 classes.
# Epoch 1/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.7740 - accuracy: 0.3547
# Epoch 1: val_accuracy improved from -inf to 0.46080, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 231s 78ms/step - loss: 1.7740 - accuracy: 0.3547 - val_loss: 1.5456 - val_accuracy: 0.4608 - lr: 0.0010
# Epoch 2/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.3871 - accuracy: 0.5065
# Epoch 2: val_accuracy improved from 0.46080 to 0.51940, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 211s 75ms/step - loss: 1.3871 - accuracy: 0.5065 - val_loss: 1.4106 - val_accuracy: 0.5194 - lr: 0.0015
# Epoch 3/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.1770 - accuracy: 0.5904
# Epoch 3: val_accuracy did not improve from 0.51940
# 2813/2813 [==============================] - 211s 75ms/step - loss: 1.1770 - accuracy: 0.5904 - val_loss: 1.8659 - val_accuracy: 0.4852 - lr: 0.0020
# Epoch 4/50
# 2813/2813 [==============================] - ETA: 0s - loss: 1.0495 - accuracy: 0.6353
# Epoch 4: val_accuracy improved from 0.51940 to 0.58240, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 1.0495 - accuracy: 0.6353 - val_loss: 1.2536 - val_accuracy: 0.5824 - lr: 0.0025
# Epoch 5/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.9617 - accuracy: 0.6694
# Epoch 5: val_accuracy improved from 0.58240 to 0.64880, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.9617 - accuracy: 0.6694 - val_loss: 1.0425 - val_accuracy: 0.6488 - lr: 0.0030
# Epoch 6/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.8950 - accuracy: 0.6917
# Epoch 6: val_accuracy improved from 0.64880 to 0.65820, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.8950 - accuracy: 0.6917 - val_loss: 1.1325 - val_accuracy: 0.6582 - lr: 0.0035
# Epoch 7/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.8493 - accuracy: 0.7106
# Epoch 7: val_accuracy improved from 0.65820 to 0.68140, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.8493 - accuracy: 0.7106 - val_loss: 0.9501 - val_accuracy: 0.6814 - lr: 0.0040
# Epoch 8/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.7952 - accuracy: 0.7304
# Epoch 8: val_accuracy did not improve from 0.68140
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.7952 - accuracy: 0.7304 - val_loss: 1.0493 - val_accuracy: 0.6736 - lr: 0.0040
# Epoch 9/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.7099 - accuracy: 0.7592
# Epoch 9: val_accuracy improved from 0.68140 to 0.74100, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.7099 - accuracy: 0.7592 - val_loss: 0.8355 - val_accuracy: 0.7410 - lr: 0.0034
# Epoch 10/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.6429 - accuracy: 0.7814
# Epoch 10: val_accuracy did not improve from 0.74100
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.6429 - accuracy: 0.7814 - val_loss: 0.7970 - val_accuracy: 0.7346 - lr: 0.0029
# Epoch 11/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5882 - accuracy: 0.7981
# Epoch 11: val_accuracy improved from 0.74100 to 0.78060, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5882 - accuracy: 0.7981 - val_loss: 0.6861 - val_accuracy: 0.7806 - lr: 0.0025
# Epoch 12/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.8146
# Epoch 12: val_accuracy improved from 0.78060 to 0.80560, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5450 - accuracy: 0.8146 - val_loss: 0.5750 - val_accuracy: 0.8056 - lr: 0.0021
# Epoch 13/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.8319
# Epoch 13: val_accuracy did not improve from 0.80560
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.4979 - accuracy: 0.8319 - val_loss: 0.6175 - val_accuracy: 0.7906 - lr: 0.0018
# Epoch 14/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4720 - accuracy: 0.8390
# Epoch 14: val_accuracy improved from 0.80560 to 0.82680, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.4720 - accuracy: 0.8390 - val_loss: 0.5099 - val_accuracy: 0.8268 - lr: 0.0015
# Epoch 15/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4487 - accuracy: 0.8481
# Epoch 15: val_accuracy improved from 0.82680 to 0.83900, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.4487 - accuracy: 0.8481 - val_loss: 0.4656 - val_accuracy: 0.8390 - lr: 0.0013
# Epoch 16/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4168 - accuracy: 0.8553
# Epoch 16: val_accuracy improved from 0.83900 to 0.84820, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.4168 - accuracy: 0.8553 - val_loss: 0.4499 - val_accuracy: 0.8482 - lr: 0.0011
# Epoch 17/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3979 - accuracy: 0.8624
# Epoch 17: val_accuracy improved from 0.84820 to 0.85860, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3979 - accuracy: 0.8624 - val_loss: 0.4162 - val_accuracy: 0.8586 - lr: 9.2647e-04
# Epoch 18/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8702
# Epoch 18: val_accuracy did not improve from 0.85860
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3819 - accuracy: 0.8702 - val_loss: 0.4377 - val_accuracy: 0.8488 - lr: 7.8750e-04
# Epoch 19/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8734
# Epoch 19: val_accuracy did not improve from 0.85860
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3673 - accuracy: 0.8734 - val_loss: 0.4329 - val_accuracy: 0.8536 - lr: 6.6937e-04
# Epoch 20/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8800
# Epoch 20: val_accuracy improved from 0.85860 to 0.86360, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3512 - accuracy: 0.8800 - val_loss: 0.3999 - val_accuracy: 0.8636 - lr: 5.6897e-04
# Epoch 21/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.8844
# Epoch 21: val_accuracy improved from 0.86360 to 0.86540, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3381 - accuracy: 0.8844 - val_loss: 0.3984 - val_accuracy: 0.8654 - lr: 4.8362e-04
# Epoch 22/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3254 - accuracy: 0.8872
# Epoch 22: val_accuracy improved from 0.86540 to 0.87340, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3254 - accuracy: 0.8872 - val_loss: 0.3910 - val_accuracy: 0.8734 - lr: 4.1108e-04
# Epoch 23/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8927
# Epoch 23: val_accuracy did not improve from 0.87340
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3117 - accuracy: 0.8927 - val_loss: 0.3807 - val_accuracy: 0.8724 - lr: 3.4942e-04
# Epoch 24/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3117 - accuracy: 0.8936
# Epoch 24: val_accuracy did not improve from 0.87340
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3117 - accuracy: 0.8936 - val_loss: 0.3735 - val_accuracy: 0.8714 - lr: 2.9700e-04
# Epoch 25/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.8940
# Epoch 25: val_accuracy improved from 0.87340 to 0.87760, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3077 - accuracy: 0.8940 - val_loss: 0.3686 - val_accuracy: 0.8776 - lr: 2.5245e-04
# Epoch 26/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8790
# Epoch 26: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3522 - accuracy: 0.8790 - val_loss: 0.4200 - val_accuracy: 0.8608 - lr: 0.0010
# Epoch 27/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3902 - accuracy: 0.8685
# Epoch 27: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3902 - accuracy: 0.8685 - val_loss: 0.4861 - val_accuracy: 0.8416 - lr: 0.0015
# Epoch 28/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4284 - accuracy: 0.8538
# Epoch 28: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.4284 - accuracy: 0.8538 - val_loss: 0.4765 - val_accuracy: 0.8394 - lr: 0.0020
# Epoch 29/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4682 - accuracy: 0.8405
# Epoch 29: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.4682 - accuracy: 0.8405 - val_loss: 0.6476 - val_accuracy: 0.7892 - lr: 0.0025
# Epoch 30/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8318
# Epoch 30: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5049 - accuracy: 0.8318 - val_loss: 0.6685 - val_accuracy: 0.7792 - lr: 0.0030
# Epoch 31/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.8194
# Epoch 31: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5392 - accuracy: 0.8194 - val_loss: 0.5741 - val_accuracy: 0.8118 - lr: 0.0035
# Epoch 32/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5688 - accuracy: 0.8099
# Epoch 32: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5688 - accuracy: 0.8099 - val_loss: 0.6648 - val_accuracy: 0.7804 - lr: 0.0040
# Epoch 33/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5621 - accuracy: 0.8130
# Epoch 33: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.5621 - accuracy: 0.8130 - val_loss: 0.5976 - val_accuracy: 0.8070 - lr: 0.0040
# Epoch 34/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.5076 - accuracy: 0.8308
# Epoch 34: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.5076 - accuracy: 0.8308 - val_loss: 0.5946 - val_accuracy: 0.8058 - lr: 0.0034
# Epoch 35/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4756 - accuracy: 0.8406
# Epoch 35: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.4756 - accuracy: 0.8406 - val_loss: 0.5532 - val_accuracy: 0.8230 - lr: 0.0029
# Epoch 36/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8531
# Epoch 36: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.4365 - accuracy: 0.8531 - val_loss: 0.4979 - val_accuracy: 0.8390 - lr: 0.0025
# Epoch 37/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.4050 - accuracy: 0.8631
# Epoch 37: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.4050 - accuracy: 0.8631 - val_loss: 0.4544 - val_accuracy: 0.8522 - lr: 0.0021
# Epoch 38/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3850 - accuracy: 0.8721
# Epoch 38: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3850 - accuracy: 0.8721 - val_loss: 0.4768 - val_accuracy: 0.8422 - lr: 0.0018
# Epoch 39/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3571 - accuracy: 0.8802
# Epoch 39: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3571 - accuracy: 0.8802 - val_loss: 0.4302 - val_accuracy: 0.8618 - lr: 0.0015
# Epoch 40/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8868
# Epoch 40: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3374 - accuracy: 0.8868 - val_loss: 0.4061 - val_accuracy: 0.8648 - lr: 0.0013
# Epoch 41/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3210 - accuracy: 0.8903
# Epoch 41: val_accuracy did not improve from 0.87760
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.3210 - accuracy: 0.8903 - val_loss: 0.4007 - val_accuracy: 0.8748 - lr: 0.0011
# Epoch 42/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.8976
# Epoch 42: val_accuracy improved from 0.87760 to 0.87980, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.3019 - accuracy: 0.8976 - val_loss: 0.3731 - val_accuracy: 0.8798 - lr: 9.2647e-04
# Epoch 43/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.9015
# Epoch 43: val_accuracy did not improve from 0.87980
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.2905 - accuracy: 0.9015 - val_loss: 0.3872 - val_accuracy: 0.8744 - lr: 7.8750e-04
# Epoch 44/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2811 - accuracy: 0.9041
# Epoch 44: val_accuracy improved from 0.87980 to 0.88220, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.2811 - accuracy: 0.9041 - val_loss: 0.3465 - val_accuracy: 0.8822 - lr: 6.6937e-04
# Epoch 45/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.9063
# Epoch 45: val_accuracy improved from 0.88220 to 0.88380, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.2729 - accuracy: 0.9063 - val_loss: 0.3693 - val_accuracy: 0.8838 - lr: 5.6897e-04
# Epoch 46/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.9102
# Epoch 46: val_accuracy improved from 0.88380 to 0.88680, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.2642 - accuracy: 0.9102 - val_loss: 0.3560 - val_accuracy: 0.8868 - lr: 4.8362e-04
# Epoch 47/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2528 - accuracy: 0.9147
# Epoch 47: val_accuracy did not improve from 0.88680
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.2528 - accuracy: 0.9147 - val_loss: 0.3587 - val_accuracy: 0.8848 - lr: 4.1108e-04
# Epoch 48/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9164
# Epoch 48: val_accuracy did not improve from 0.88680
# 2813/2813 [==============================] - 209s 74ms/step - loss: 0.2487 - accuracy: 0.9164 - val_loss: 0.3684 - val_accuracy: 0.8864 - lr: 3.4942e-04
# Epoch 49/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9185
# Epoch 49: val_accuracy did not improve from 0.88680
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.2403 - accuracy: 0.9185 - val_loss: 0.3737 - val_accuracy: 0.8856 - lr: 2.9700e-04
# Epoch 50/50
# 2813/2813 [==============================] - ETA: 0s - loss: 0.2322 - accuracy: 0.9209
# Epoch 50: val_accuracy improved from 0.88680 to 0.89600, saving model to GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 2813/2813 [==============================] - 208s 74ms/step - loss: 0.2322 - accuracy: 0.9209 - val_loss: 0.3531 - val_accuracy: 0.8960 - lr: 2.5245e-04

# %% [markdown]
# # Plotting Accuracy and Loss

# %%
# Plot the accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epoch_range = range(len(acc))

plt.plot(epoch_range, acc, label='Training accuracy')
plt.plot(epoch_range, val_acc, label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epoch_range, loss, label='Training loss')
plt.plot(epoch_range, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Evaluation of Results

# %%
gpc_mobilenetV1(generate_model=False, model_fit=False, eval_results=True)
# Out:
# Running: GPC-mobilenet-CIFAR10--1
# Found 10000 images belonging to 10 classes.
# Best Model Results: GPC-mobilenet-CIFAR10--1-best_result.hdf5
# 625/625 [==============================] - 11s 17ms/step - loss: 0.2810 - accuracy: 0.9235
# loss 0.2809569239616394
# acc 0.9235000014305115
# Finished: GPC-mobilenet-CIFAR10--1
